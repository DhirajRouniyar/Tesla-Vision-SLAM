# %% [markdown]
# ## Clone and Installation

# %%
# %cd /content/
# !rm -rf YOLO3D
# Out:
# /content

# %%
# %cd /content/
# !git clone https://github.com/ruhyadi/YOLO3D
# Out:
# /content
# Cloning into 'YOLO3D'...
# remote: Enumerating objects: 973, done.
# remote: Counting objects: 100% (340/340), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 973 (delta 169), reused 279 (delta 125), pack-reused 633
# Receiving objects: 100% (973/973), 24.83 MiB | 23.20 MiB/s, done.
# Resolving deltas: 100% (407/407), done.

# %%
# install requirements
# %cd /content/YOLO3D

# !pip install -q --upgrade --no-cache-dir gdown
# Out:
# /content/YOLO3D

# %%
# get weights
# %cd /content/YOLO3D/weights/
# !python get_weights.py --weights 'resnet18'
# Out:
# /content/YOLO3D/weights
# Downloading...
# From (original): https://drive.google.com/uc?id=1k_v1RrDO6da_NDhBtMZL5c0QSogCmiRn
# From (redirected): https://drive.google.com/uc?id=1k_v1RrDO6da_NDhBtMZL5c0QSogCmiRn&confirm=t&uuid=10e1ba2b-5d93-49a3-ae4b-8a601bbbfcc3
# To: /content/YOLO3D/weights/resnet18.pkl
# 100% 298M/298M [00:03<00:00, 82.4MB/s]

# %% [markdown]
# ## Inference

# %%
# %cd /content/YOLO3D/
# !python inference.py \
  --weights yolov5s.pt  \
  --source /content/Scene5 \
  --reg_weights weights/resnet18.pkl \
  --model_select resnet18 \
  --output_path runs01 \
  --save_result
# Out:
# /content/YOLO3D
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 170MB/s]
# inference: weights=['yolov5s.pt'], source=/content/Scene5, data=data/coco128.yaml, imgsz=[640, 640], device=, classes=[0, 2, 3, 5], reg_weights=weights/resnet18.pkl, model_select=resnet18, calib_file=eval/camera_cal/calib_cam_to_cam.txt, show_result=False, save_result=True, output_path=runs01

# %% [markdown]
# ## Show Result

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.cvtColor(cv2.imread('/content/YOLO3D/runs01/005.png'), cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !zip -r Output.zip runs01/
# Out:
#   adding: runs01/ (stored 0%)
#   adding: runs01/049.png (deflated 9%)
#   adding: runs01/036.png (deflated 8%)
#   adding: runs01/018.png (deflated 6%)
#   adding: runs01/047.png (deflated 9%)
#   adding: runs01/046.png (deflated 9%)
#   adding: runs01/013.png (deflated 7%)
#   adding: runs01/050.png (deflated 8%)
#   adding: runs01/040.png (deflated 8%)
#   adding: runs01/054.png (deflated 7%)
#   adding: runs01/003.png (deflated 6%)
#   adding: runs01/031.png (deflated 8%)
#   adding: runs01/010.png (deflated 6%)
#   adding: runs01/059.png (deflated 6%)
#   adding: runs01/000.png (deflated 6%)
#   adding: runs01/041.png (deflated 9%)
#   adding: runs01/051.png (deflated 8%)
#   adding: runs01/014.png (deflated 7%)
#   adding: runs01/007.png (deflated 6%)
#   adding: runs01/034.png (deflated 8%)
#   adding: runs01/017.png (deflated 7%)
#   adding: runs01/009.png (deflated 6%)
#   adding: runs01/033.png (deflated 7%)
#   adding: runs01/035.png (deflated 8%)
#   adding: runs01/004.png (deflated 6%)
#   adding: runs01/023.png (deflated 8%)
#   adding: runs01/019.png (deflated 6%)
#   adding: runs01/006.png (deflated 7%)
#   adding: runs01/015.png (deflated 7%)
#   adding: runs01/021.png (deflated 7%)
#   adding: runs01/055.png (deflated 7%)
#   adding: runs01/020.png (deflated 7%)
#   adding: runs01/045.png (deflated 10%)
#   adding: runs01/053.png (deflated 7%)
#   adding: runs01/024.png (deflated 8%)
#   adding: runs01/022.png (deflated 8%)
#   adding: runs01/039.png (deflated 9%)
#   adding: runs01/043.png (deflated 9%)
#   adding: runs01/044.png (deflated 9%)
#   adding: runs01/030.png (deflated 8%)
#   adding: runs01/002.png (deflated 6%)
#   adding: runs01/012.png (deflated 7%)
#   adding: runs01/056.png (deflated 6%)
#   adding: runs01/025.png (deflated 7%)
#   adding: runs01/.ipynb_checkpoints/ (stored 0%)
#   adding: runs01/028.png (deflated 9%)
#   adding: runs01/058.png (deflated 6%)
#   adding: runs01/026.png (deflated 9%)
#   adding: runs01/038.png (deflated 8%)
#   adding: runs01/011.png (deflated 7%)
#   adding: runs01/032.png (deflated 9%)
#   adding: runs01/008.png (deflated 6%)
#   adding: runs01/027.png (deflated 9%)
#   adding: runs01/048.png (deflated 9%)
#   adding: runs01/037.png (deflated 8%)
#   adding: runs01/001.png (deflated 6%)
#   adding: runs01/052.png (deflated 7%)
#   adding: runs01/042.png (deflated 8%)
#   adding: runs01/057.png (deflated 6%)
#   adding: runs01/005.png (deflated 6%)
#   adding: runs01/029.png (deflated 9%)
#   adding: runs01/016.png (deflated 7%)
